# %%
#get data
from pycaret.datasets import get_data
import pandas as pd
data = pd.read_csv('./seiseki.csv')

# %%
#Initialize Setup
from pycaret.regression import *
exp_1 = setup(data, target = '国語')
# Out:
# <style type="text/css">
# #T_f5483_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f5483_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f5483_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f5483_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_f5483_row0_col1" class="data row0 col1" >1052</td>
#     </tr>
#     <tr>
#       <th id="T_f5483_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f5483_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f5483_row1_col1" class="data row1 col1" >国語</td>
#     </tr>
#     <tr>
#       <th id="T_f5483_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f5483_row2_col0" class="data row2 col0" >Original Data</td>
# ...

# %%
#モデルとの比較
compare_models()
# Out:
# <style type="text/css">
# #T_771ec_ th {
#   text-align: left;
# }
# ...

# %%
lr = create_model("lr")
# Out:
# <style type="text/css">
# #T_807fb_row10_col0, #T_807fb_row10_col1, #T_807fb_row10_col2, #T_807fb_row10_col3, #T_807fb_row10_col4, #T_807fb_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_807fb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_807fb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_807fb_row0_col0" class="data row0 col0" >0.2898</td>
#       <td id="T_807fb_row0_col1" class="data row0 col1" >0.1218</td>
#       <td id="T_807fb_row0_col2" class="data row0 col2" >0.3490</td>
# ...

# %%
#チューニング
tune_lr = tune_model(lr)
# Out:
# <style type="text/css">
# #T_e99fa_row10_col0, #T_e99fa_row10_col1, #T_e99fa_row10_col2, #T_e99fa_row10_col3, #T_e99fa_row10_col4, #T_e99fa_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_e99fa_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e99fa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e99fa_row0_col0" class="data row0 col0" >0.2898</td>
#       <td id="T_e99fa_row0_col1" class="data row0 col1" >0.1218</td>
#       <td id="T_e99fa_row0_col2" class="data row0 col2" >0.3490</td>
# ...

# %%
tune_lr.get_params
# Out:
# <bound method BaseEstimator.get_params of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=-1, normalize=False)>

# %%
#モデルの可視化
plot_model(tune_lr)

# %%
plot_model(tune_et, plot='feature')

# %%
#予測
predict_model(tune_lr)
# Out:
# <style type="text/css">
# </style>
# <table id="T_7ec60_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ec60_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7ec60_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_7ec60_row0_col1" class="data row0 col1" >0.2931</td>
#       <td id="T_7ec60_row0_col2" class="data row0 col2" >0.1243</td>
#       <td id="T_7ec60_row0_col3" class="data row0 col3" >0.3526</td>
# ...
